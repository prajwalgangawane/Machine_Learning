# %% [markdown]
# # Assignment 1 – SET 3
#
# ## Group - 107
#
# ### Dataset: Airfoil Self Noise Dataset

# %% [markdown]
# ###### Import Libraries/Dataset

# %% [markdown]
# 1. Download the dataset : https://archive.ics.uci.edu/ml/machine-learning-databases/00291/airfoil_self_noise.dat

# %% [markdown]
# 2. Import the required libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 1. Data Visualization and Exploration [1 M]

# %% [markdown]
# ###### 1. Print 2 rows for sanity check to identify all the features present in the dataset and if the target matches with them.

# %%
# directly checking the 2 values as we are unaware of columns keeping 'header=None'
airfoil = pd.read_csv('airfoil_self_noise.dat', sep="\t", header=None) 
airfoil.head(2)
# Out:
#       0    1       2     3         4        5
# 0   800  0.0  0.3048  71.3  0.002663  126.201
# 1  1000  0.0  0.3048  71.3  0.002663  125.201

# %% [markdown]
# This dataset has the following parameters for airfoil captured while having an experiment with an airfoil:
# - Frequency, in Hertzs.
# - Angle of attack, in degrees.
# - Chord length, in meters.
# - Free-stream velocity, in meters per second.
# - Suction side displacement thickness, in meters.
# - Scaled sound pressure level, in decibels.

# %%
# naming each dataset column
columns = [
    "Frequency",
    "Angle of Attack", 
    "Chord Length",
    "Free-stream Velocity",
    "Suction side displacement thickness",
    "Scaled Sound Pressure Level"
]  
# columns = [ 'f', 'aa', 'cl', 'fvs', 'ssdt', 'sspl' ] 
airfoil = pd.read_csv('airfoil_self_noise.dat', sep="\t", names = columns) # Airfoil dataset loaded
airfoil.head(2) # showing 2 values
# Out:
#    Frequency  Angle of Attack  Chord Length  Free-stream Velocity  \
# 0        800              0.0        0.3048                  71.3
# 1       1000              0.0        0.3048                  71.3
#
#    Suction side displacement thickness  Scaled Sound Pressure Level
# 0                             0.002663                      126.201
# 1                             0.002663                      125.201

# %%
airfoil.shape  # (Number of rows, Number of columns)
# Out:
# (1503, 6)

# %%
airfoil.info() # Showing the count of null values and dtype or each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Frequency                            1503 non-null   int64
#  1   Angle of Attack                      1503 non-null   float64
#  2   Chord Length                         1503 non-null   float64
#  3   Free-stream Velocity                 1503 non-null   float64
#  4   Suction side displacement thickness  1503 non-null   float64
#  5   Scaled Sound Pressure Level          1503 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 70.6 KB

# %%
airfoil.describe() # Displaying basic statistical calculations related to dataset
# Out:
#           Frequency  Angle of Attack  Chord Length  Free-stream Velocity  \
# count   1503.000000      1503.000000   1503.000000           1503.000000
# mean    2886.380572         6.782302      0.136548             50.860745
# std     3152.573137         5.918128      0.093541             15.572784
# min      200.000000         0.000000      0.025400             31.700000
# 25%      800.000000         2.000000      0.050800             39.600000
# 50%     1600.000000         5.400000      0.101600             39.600000
# 75%     4000.000000         9.900000      0.228600             71.300000
# max    20000.000000        22.200000      0.304800             71.300000
#
#        Suction side displacement thickness  Scaled Sound Pressure Level
# count                          1503.000000                  1503.000000
# mean                              0.011140                   124.835943
# std                               0.013150                     6.898657
# ...

# %% [markdown]
# ###### 2. Comment on class imbalance with appropriate visualization method.

# %%
fig, axis = plt.subplots(1,figsize=(10,5))
sns.histplot(data=df_self_noise, x='scaled_sound_press_db',bins=20, kde=True)
# Out:
# 0       126.201
# 1       125.201
# 2       125.951
# 3       127.591
# 4       127.461
#          ...
# 1498    110.264
# 1499    109.254
# 1500    106.604
# 1501    106.224
# 1502    104.204
# Name: Scaled Sound Pressure Level, Length: 1503, dtype: float64

# %% [markdown]
# The above boxplot shows us the outliers in the columns
# - Frequency
# - Angle of Attack
# - Suction side displacement thickness
# - Scaled Sound Pressure Level

# %%
sns.heatmap(airfoil.isnull())
# Out:
# <AxesSubplot: >

# %%
# sns.pairplot(airfoil[columns[:-1]])
sns.pairplot(airfoil)
